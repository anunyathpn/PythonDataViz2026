# %% [markdown]
# <a href="https://colab.research.google.com/github/anunyathpn/PythonDataViz2026/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HW3

# %% [markdown]
# ### HW คำนวณเวลาเป็นวินาทีของเวลาต่อไปนี้โดยใช้คำสั่ง split() ช่วย (print ออกมาให้สวยงาม)
# 12:30:15
#
# 13:41:07
#
# 12:53:15
#
# 00:59:25
#
# 11:11:11
#
# 16:06:09

# %% [markdown]
# ## ให้สร้างฟังก์ชั่นคำนวณเวลาเป็นวินาทีของเวลาใดๆ และ print ออกมาให้สวยงาม

# %% [markdown]
# ## ให้ สร้าง list ของ เวลา ```['12:30:15','13:41:07',....]``` แล้ววนลูปเรียกฟังก์ชั่นคำนวณเวลาเป็น วินาที
#
# **commit ว่า HW3**

# %%
def time_sec(time):
     t = time.split(':')
     total_sec = (int(t[0])*3600) + (int(t[1])*60) + int(t[2])
     return total_sec

# %%
times = [
    '12:30:15',
    '13:41:07',
    '12:53:15',
    '00:59:25',
    '11:11:11',
    '16:06:09'
]

# %%
for time in times:
    total_sec =  totalsec(time)
    print(f'เวลา {time} เท่ากับ {total_sec:,} วินาที')
# Out:
# เวลา 12:30:15 เท่ากับ 45,015 วินาที
# เวลา 13:41:07 เท่ากับ 49,267 วินาที
# เวลา 12:53:15 เท่ากับ 46,395 วินาที
# เวลา 00:59:25 เท่ากับ 3,565 วินาที
# เวลา 11:11:11 เท่ากับ 40,271 วินาที
# เวลา 16:06:09 เท่ากับ 57,969 วินาที
