# %% [markdown]
# <a href="https://colab.research.google.com/github/anunyathpn/PythonDataViz2026/blob/main/HW0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # อนัญญา ทองปน

# %%
print('ID673020268-9')
# Out:
# ID673020268-9
